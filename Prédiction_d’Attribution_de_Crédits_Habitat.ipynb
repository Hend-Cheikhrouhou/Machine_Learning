# %% [markdown]
# <a href="https://colab.research.google.com/github/Hend-Cheikhrouhou/Machine_Learning/blob/main/Pr%C3%A9diction_d%E2%80%99Attribution_de_Cr%C3%A9dits_Habitat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prédiction d’Attribution de Crédits Habitat : Pipeline de Data Science & Exploration des Données

# %% [markdown]
# C'est ma premiere cellule

# %% [markdown]
# Il s'agit d'un projet de prédiction d'attribution de Crédits Habitat à une clientèle d'une Banque.
#
# On va suivre ce qu'on appelle un data science/machine learning pipeline. Pour commencer, on va explorer 2 datasets qui accompagnent cette phase. Avant de passer au prétraitement, on va:
#
# Etape1- Compréhension du problème et exploration des variables de nos datasets
#
# Etape2- émission des hypothèses
#
# Etape3- Analyse Exporatoire des Données (AED) ou bien Exploratory Data Analysis (EDA)
#
#        i)  Analyse Univariée
#
#        ii) Analyse Bivariée

# %% [markdown]
# ## Etape1

# %% [markdown]
# Afin de comprendre le problème à traiter, il s'agit de l'Exploration des variables de nos datasets.
#
# Il faut importer la bibliothèque Pandas de Python ainsi qu'une panoplie de bibliothèques dont on aura besoin après.

# %%
import pandas as pd # c'est pour manipuler les dataframes
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [raw]
# On va charger le dataset Partie1DatasetTP2.csv qui contient la première partie de nos données

# %%
# C'est un commentaire sur une seule ligne
#  pd est un objet de type pandas déclaré en haut pour pouvoir évoquer des méthodes de
# la bibliothèque Pandas: on aurait pu l'appeler x
# df1 est un objet de type dataframe: cadre de données. On va manipuler des dataframes
#  read_csv permet d'ouvrir le dataset contenu dans le fichier "Partie1DatasetTP2.csv" et de mettre le contenu dans df1
# Il faut indiquer le chemin d'accès si c'est nécessaire exemple c:/mesTps...
""" c'est un
commentaire sur plusieurs lignes avec python"""
df1 = pd.read_csv("C:/Users/PC/Downloads/Partie1DatasetTP2.csv")
print ("fichier ouvert le")
from datetime import datetime
now = datetime.now()
print (now)
# Out:
# fichier ouvert le
# 2023-11-14 12:05:09.427287

# %%
#Affichage du contenu du dataframe df1 qu'on a crée à partir de notre fichier .csv
#On peut utiliser print également mais
#le nom du dataframe tt court est plus pratique
df1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %% [raw]
# Entête du datset; head
# on peut spécifier un nombre entre parenthèses

# %%
df1.head(2)  # vous pouvez afficher un autre nombre au lieu de 2, si vous ne mettez rien il affiche les 5 premiers
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N

# %%
#On va afficher les infos relatives à notre dataset tels que le nombre d'attributs, les types...
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df1.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %% [raw]
# Forme du Dataset df1

# %%
print ("Les dimensions du dataset sont (nombre de ligne,nombre de colonnes)=",df1.shape)
# Out:
# Les dimensions du dataset sont (nombre de ligne,nombre de colonnes)= (614, 13)

# %% [raw]
# Conversion d'un dataframe en fichier csv (culturel)

# %%
nomfich= r"monfich.csv"
df1.to_csv('nomfich.csv', index=False)

# %% [markdown]
# ### Etape1: Activité1
# 1-Citer et détailler les variables catégorielles  de ce dataset
#
#
# 2-Citer et détailler les variables numériques de ce dataset

# %% [raw]
# Vous pouvez les citer manuellement en lisant dans les résultats des instructions précédentes ou répondre avec 2 instructions python en se basant sur les instructions ci-dessous.

# %%
df1.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df1.describe (include= "number")
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df1.describe (include= "object")
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        614    601     611        599       614           582
# unique       614      2       2          4         2             2
# top     LP001002   Male     Yes          0  Graduate            No
# freq           1    489     398        345       480           500
#
#        Property_Area Loan_Status
# count            614         614
# unique             3           2
# top        Semiurban           Y
# freq             233         422

# %% [markdown]
# ### Etape1: Activité2
# 1-Afficher le contenu de df2 qui va contenir le résultat de l'ouverture du fichier csv intitulé "Partie2DatasetTP2.csv", sa forme, ses colonnes, son entête
#
# 2-Quelles sont les différences entre les 2 dataframes: nombre d'attributs et contenu en général
#
#
# 4-Quelles sont les variables cibles et les variables explicatives

# %%
df2 = pd.read_csv("C:/Users/PC/Downloads/Partie2DatasetTP2.csv")

# %%
df2
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# 1               3076               1500       126.0             360.0
# 2               5000               1800       208.0             360.0
# 3               2340               2546       100.0             360.0
# 4               3276                  0        78.0             360.0
# ..               ...                ...         ...               ...
# 362             4009               1777       113.0             360.0
# 363             4158                709       115.0             360.0
# 364             3250               1993       126.0             360.0
# 365             5000               2393       158.0             360.0
# 366             9200                  0        98.0             180.0
#
#      Credit_History Property_Area
# 0               1.0         Urban
# 1               1.0         Urban
# 2               1.0         Urban
# 3               NaN         Urban
# 4               1.0         Urban
# ..              ...           ...
# 362             1.0         Urban
# 363             1.0         Urban
# 364             NaN     Semiurban
# 365             1.0         Rural
# 366             1.0         Rural
#
# [367 rows x 12 columns]

# %%
df2.head(2)  # vous pouvez afficher un autre nombre au lieu de 2, si vous ne mettez rien il affiche les 5 premiers
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001015   Male     Yes          0  Graduate            No
# 1  LP001022   Male     Yes          1  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban

# %%
df2.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %%
print ("Les dimensions du dataset sont (nombre de ligne,nombre de colonnes)=",df2.shape)
# Out:
# Les dimensions du dataset sont (nombre de ligne,nombre de colonnes)= (367, 12)

# %% [markdown]
# réponse question 2 : il y a une colonne qui disparaitre de df1 à df2

# %% [markdown]
# réponse question 3 : le variable loan_status est un variable cible puisque il est disparaitre entre df1 et df2, et les autres sont des variables explicatives

# %% [markdown]
# ## Etape2 : Emission des hypothèses

# %% [raw]
# Il s'agit d'émettre des hypothèses qu'on pourra vérifier dans ce qui suit via l'étape3 de l'AED Qui est l'analyse exploratoire bivariée du Dataset
# 1) Les demandeurs de crédit avec de grands salaires ou 'income' ont beaucoup plus de chances d'avoir une acceptation de crédit
# 2) Les demandeurs de crédit ayant payé leurs anciennes dettes (credit history) ont beaucoup plus de chances d'avoir une acceptation de crédit
# 3) Plus le montant de crédit demandé est petit (LoanAmount), plus les chances d'acceptation de la demande de crédit sont grandes.
# 4) Plus la mensulatité du crédit est plus petite (Loan_Amount_Term est plus grand), plus les chances d'acceptation de la demande de crédit sont grandes.

# %% [markdown]
# ## Etape3: AED

# %% [markdown]
# ### A- Analyse univariée des variables

# %% [markdown]
# ### A-1Variable cible

# %% [raw]
# On va étudier la variable catégorielle cible Réponse_demande_crédit désignée par Loan_Status dans le dataset

# %%
df1["Loan_Status"].value_counts()
# Out:
# Y    422
# N    192
# Name: Loan_Status, dtype: int64

# %%
df1["Loan_Status"].value_counts()[1] # si on veut afficher le nombre d'éléments du 2ème type
# Out:
# 192

# %% [raw]
# Diagramme en barre de la variable catégorielle cible Réponse_demande_crédit désignée par Loan_Status

# %%
sns.countplot(x='Loan_Status', data = df1);
# On peut mettre aussi
#sns.countplot(df1['Loan_Status']);
print('Le pourcentage de classe Y (acceptation de crédit) : %.2f' % (df1['Loan_Status'].value_counts()[0] / len(df1)))
print('Le poucentage de classe N (Refus de crédit) : %.2f' % (df1['Loan_Status'].value_counts()[1] / len(df1)))

#On peut considérer que c'est un datset imbalanced
# Out:
# Le pourcentage de classe Y (acceptation de crédit) : 0.69
# Le poucentage de classe N (Refus de crédit) : 0.31

# %% [raw]
# Une autre manière de faire le diagramme en Barre

# %%
#df1["Loan_Status"].value_counts(normalize=True).plot.bar(title = 'Réponse_Demande_crédit') ou
df1["Loan_Status"].value_counts().plot.bar(title = 'Réponse_Demande_crédit')
# Out:
# <AxesSubplot:title={'center':'Réponse_Demande_crédit'}>

# %% [markdown]
# ### A-2 Variables indépendantes catégorielles

# %%
# Variable indépendante caégorielle genre ou "Gender"
df1["Gender"].value_counts()
# Out:
# Male      489
# Female    112
# Name: Gender, dtype: int64

# %%
sns.countplot(x='Gender', data = df1);

# %%
# Variable indépendante catégorielle Historique de crédit ou"Credit_History"
df1["Credit_History"].value_counts()
# Out:
# Credit_History
# 1.0    475
# 0.0     89
# Name: count, dtype: int64

# %%
#df1['Dependents'].value_counts(normalize=True).plot.bar(title="Dependents")
#'''ou bien'''
sns.countplot(x='Education', data = df1);

# %%
#df1['Dependents'].value_counts(normalize=True).plot.bar(title="Dependents")
#'''ou bien'''
sns.countplot(x='Self_Employed', data = df1);

# %%
sns.countplot(x='Married', data = df1);

# %%
sns.countplot(x='Property_Area', data = df1);

# %% [markdown]
# ### Etape3: Activité1

# %% [raw]
# On vous demande de terminer le même travail pour le reste des variables catégorielles de df1

# %% [markdown]
# ### A-3 Variables numériques
#
# > Ajouter une citation

# %% [raw]
# Les variables numériques peuvent être représentées par des histogrammes  ou des boîtes à moustaches

# %%
sns.displot(df1["ApplicantIncome"]);

# %%
sns.boxplot(df1["ApplicantIncome"])
# Out:
# C:\Users\sina2\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ApplicantIncome'>

# %% [markdown]
# ### Comment interpréter une boîte à moustache

# %%
print(df1.describe(include='number')) #ça nous aide pour lire les valeurs des médianes, quartiles Q1, Q3
# print(df1.describe(include='object')) #pour les var catégorielles...
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
#Si on veut explorer les valeurs d'une variable spécifique pour bien interpréter le boxplot
df1['ApplicantIncome'].describe()
# Out:
# count      614.000000
# mean      5403.459283
# std       6109.041673
# min        150.000000
# 25%       2877.500000
# 50%       3812.500000
# 75%       5795.000000
# max      81000.000000
# Name: ApplicantIncome, dtype: float64

# %% [markdown]
# # Récapitulons (PartieA): Analyse univariée

# %% [raw]
# Récapitulons:
# Nous avons vu l'analyse univariée
# Nous avons utilisé pour les variables catégorielles : countplot de seaborn ou plot.bar pour générer des diagrammes à bar (bar charts)
# Nous avons utilisé distplot de seaborn pour les variables numériques pour générer des histogrammes et nous avons utilisé boxplot pour les boîtes à moustaches pour se concentrer sur les outliers, la médiane, les quartiles

# %% [markdown]
# ### B-Analyse bi-variée

# %%
# c'est une analyse bi-variée entre le salaire et l'éducation
df1.boxplot(column='ApplicantIncome',by="Education" )
# Out:
# <AxesSubplot:title={'center':'ApplicantIncome'}, xlabel='Education'>

# %% [raw]
# On remarque qu'il existe beaucoup d'outliers vu que nous sommes entrain d'étudier des salaires des gens qui ont des niveaux d'éduaction différents.

# %%
#Credit_History
sns.countplot(x='Credit_History', hue='Loan_Status', data=df1, linewidth=5);

# %% [raw]
# On n'accorde pas un crédit aux personnes avec Credit History = 0
# Par contre on accorde un crédit aux personnes ayant un Credit History = 1
# Donc on peut déduire que si on a Credit History = 1 , on a plus de chance d'avoir un crédit
# Credi_History est une caractéristique importante pour décider du résultat de la demande de crédit (important feature)

# %%
sns.countplot(x='Gender', hue='Loan_Status', data=df1, linewidth=5);

# majorité des hommes ont eu un crédit et une majorité de femmes aussi: il n'y a pas un modèle (No pattern)

# Ce n'est pas un important feature...

# %%
sns.countplot(x='Married', hue='Loan_Status', data=df1, linewidth=5);
# ou avec couleurs
#sns.countplot(x='Married', hue='Loan_Status', data=df1, color="deeppink", linewidth=5);

# %% [raw]
# La majorité des personnes mariées ont eu un crédit
# Si vous êtes mariés vous avez beaucoup plus de chances d'avoir un crédit :)

# %%
# Dependents
# Donner le code nécessaire


# Discussion: Si Dependents = 0 , on a beaucoup plus de chances d'avoir un crédit ((very high chance))

# %%
# Education
# Donner le code nécessaire


# Si vous êtes garduate ou pas, vous avez presque la même chance d'avoir un crédit (No pattern)
# La majorité des gens éduqués (graduate) ont eu un crédit
# Les personnes not graduate ont eu un crédit, mais avec moins de pourcentage
# Les personnes garduate sont plus nombreuses à avoir un refus de crédit!

# %%
# Self_Employed et Loan_Status
# c'est une autre manière de faire des bar plot (culturel)
# Donner une interprétation
grid = sns.FacetGrid(df1,col='Loan_Status', height =3.2, aspect=1.6)
grid.map(sns.countplot, 'Self_Employed', color="aqua")
# Out:
# C:\Users\sina2\anaconda3\lib\site-packages\seaborn\axisgrid.py:670: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
#ApplicantIncome et Loan_Status
df1.boxplot(column='ApplicantIncome',by="Loan_Status" )
# Out:
# <AxesSubplot:title={'center':'ApplicantIncome'}, xlabel='Loan_Status'>

# %% [raw]
# Discussion: on constate que 'ApplicantIncome'a un effet positif sur'Loan_Status', c'est à dire plus les salaires sont élevés plus il aura de chance d'avoir un crédit

# %% [markdown]
# ### Etape3: Activité2
#  Terminer votre analyse bi-variée et faire les inductions nécessaires

# %% [markdown]
# # Correlation entre variables

# %% [markdown]
# ### On va changer le type de loan_status pour pouvoir calculer sa corrélation avec les autres variables numériques du dataset

# %%
df1["Loan_Status"]= df1["Loan_Status"].replace("Y",1)
df1["Loan_Status"]= df1["Loan_Status"].replace("N",0)

df1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area  Loan_Status
# 0               1.0         Urban            1
# 1               1.0         Rural            0
# 2               1.0         Urban            1
# 3               1.0         Urban            1
# 4               1.0         Urban            1
# ..              ...           ...          ...
# 609             1.0         Rural            1
# 610             1.0         Rural            1
# 611             1.0         Urban            1
# 612             1.0         Urban            1
# 613             0.0     Semiurban            0
#
# [614 rows x 13 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 62.5+ KB

# %%
#On peut mettre le paramètre hue ou pas...
sns.pairplot(df1, hue="Loan_Status",diag_kind="hist" )

# %% [raw]
# Autre méthode

# %%
#sns.heatmap(df1.corr()) ou
#plt.figure(figsize=(15, 10)) #vous pouvez utiliser cette instruction pour gérer la taille de la matrice
numeric_columns=df1.select_dtypes(include=[int,float])
matrix = numeric_columns.corr()
sns.heatmap(matrix, vmax=.8, square=True, cmap="plasma",annot=True,linewidths=.1);

# %% [markdown]
# ### Etape3: Activité3
# On vous demande de faire les interprétations nécessaires et de changer le thème de la matrice de correlation.

# %% [raw]
# 1)j'ai changé le théme pour"plasma"
# 2)les interprétations:
#
# il existe une faible coorélation négative: -0.06/-0.12/-0.059/-0.045/-0.037/-0.015/-0.0021/-0.0047/-0.0084
# il existe une faible coorélation positive: 0.19/0.039/0.0015
# il existe une moyenne coorélation: 0.56 / 0.57
# *il existe une moyenne coorélation de 0.57 entre Applicantincome et LoanAmount
# *il existe une moyenne corrélation de 0.56 entre Credit_History et Loan_Status
# il est parfaitement cooréller avec elle même: au niveau du diagolane (1) (puique c'est une matrice symetrique).
